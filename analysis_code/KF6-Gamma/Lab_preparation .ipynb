# %% [markdown]
# # Preparation videos for the labs:

# %% [markdown]
# - Radiation interaction with matter
# - Detector Types
# - Signal processing

# %%
from IPython.lib.display import YouTubeVideo

# %% [markdown]
# # Radiation Interaction with Matter

# %% [markdown]
# Basic video, but has a great idea: shows when alpha and beta radiation is stopped with Geiger counter.

# %%
YouTubeVideo('iTb_KRG6LXo')

# %% [markdown]
# Another demonstration:

# %%
YouTubeVideo('io9nMX2CLq4')

# %% [markdown]
# # Detectors

# %% [markdown]
# ### Gas detectors:

# %%
YouTubeVideo('Jdyiym7GVIQ')

# %% [markdown]
# Ion chambers vs Geiger-Müller tube

# %%
YouTubeVideo('eSUR_lpBV0E')

# %% [markdown]
# Geiger counter:

# %%
YouTubeVideo('qtvz8lH5zhk')

# %% [markdown]
# ### Scintillator detectors:

# %%
YouTubeVideo('DNnzHQ5p0nc')

# %% [markdown]
# ### Semicondutor detectors:

# %%
YouTubeVideo('PuZWoHa9mBo')

# %% [markdown]
# # Gamma lab:

# %% [markdown]
# ### Internal conversion:

# %%
YouTubeVideo('JnOALUew5f8')
